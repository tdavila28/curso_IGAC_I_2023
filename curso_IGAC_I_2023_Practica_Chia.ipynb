# %% [markdown]
# <a href="https://colab.research.google.com/github/tdavila28/curso_IGAC_I_2023/blob/main/curso_IGAC_I_2023_Practica_Chia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Practica: Exploración de datos espaciales. Caso estudio: Municipio de Chía**

# %% [markdown]
# En este ejercicio, se sugiere reutilizar las líneas de código del ejemplo de Nuquí. Adicionalmente, se invita a la exploración de las librerias y funciones utilizadas en el ejemplo de Nuquí, entre otros, en recursos como: <br> [👉 geopandas](https://geopandas.org/) <br> [👉 gdal](https://gdal.org/) <br> [👉 matplotlib](https://matplotlib.org/) <br> [👉 rasterio](https://rasterio.readthedocs.io/en/latest/index.html) <br> [👉 plotly](https://plotly.com/python/) <br> [👉 Tutoriales con el profesor Qiusheng Wu](https://www.youtube.com/@giswqs)

# %% [markdown]
# #Alistamiento del entorno#

# %%
import glob
import os

# %% [markdown]
# **0. Incluya las librerías que considere necesarias para su ejercicio.**

# %% [markdown]
# #Importación de datos#

# %%
# %%capture
# !wget https://github.com/tdavila28/curso_IGAC_I_2023/raw/main/Chia_practica.zip
# !unzip -o /content/Chia_practica.zip
# !rm /content/Chia_practica.zip

# %%
ubicacion_shps = glob.glob(os.path.join("/content/Chia_practica/","*.shp"))
ubicacion_shps = sorted(ubicacion_shps)
ubicacion_shps
# Out:
# ['/content/Chia_practica/amb_paramos_chia.shp',
#  '/content/Chia_practica/area_estudio.shp',
#  '/content/Chia_practica/centros_poblados_chia.shp',
#  '/content/Chia_practica/coberturas_chia.shp',
#  '/content/Chia_practica/coberturas_tierra_2005_2009.shp',
#  '/content/Chia_practica/drenajes_chia.shp',
#  '/content/Chia_practica/humedales_chia.shp',
#  '/content/Chia_practica/vias_chia.shp']

# %% [markdown]
# **1. Importar las 8 capas que anteriormente se descargaron de Github.**

# %% [markdown]
# # Chequeo de la importación

# %% [markdown]
# **2. Desplegar los metadatos del sistema de coordenadas de referencia de las capas importadas.**

# %% [markdown]
# **3. Graficar y desplegar las tablas de los *GeoDataFrames* para verificar las geometrias de las capas importadas de la zona de estudio.**

# %% [markdown]
# #Exploración de datos#

# %% [markdown]
# **4. Realizar un análisis descriptivo de las tablas de atributos y de las salidas gráficas, mediante el uso de:**
# *   Tipos de datos en las tablas de cada *GeoDataFrame*
# *   Cálculo de áreas
# *   Tablas de frecuencias
# *   Gráficos de barras

# %% [markdown]
# #Geoprocesamiento de datos espaciales#

# %% [markdown]
# **5. Realice un buffer de 200 metros a la geometría de la segunda capa en la lista de capas importadas y agregue un campo llamado *area_total* para recalcular el área en hectáreas.**

# %% [markdown]
# **6. Realice intersecciones y uniones de las capas utilizadas, de acuerdo a:**
# *   Capas ambientales
# *   Capas sociales
# *   Vías y redes de drenaje
#
# **¿Qué diferencias espaciales y en tablas de atributos identifica? ¿Cómo interpreta los resultados?**

# %% [markdown]
# **7. Reclasifique y disuelva el resultado de la unión y la intersección de sus capas ambientales. (Recuerde agregar un campo de valor común para disolver) ¿Qué diferencias observa?**

# %% [markdown]
# **8. Realice la conversión del resultado previo a formato *GeoTIFF*. (Ajuste los parámetros de la rasterización teniendo en cuenta la máscara del municipio que se encuentra en el directorio raiz bajo el nombre de *chia_mask.tif*)**

# %% [markdown]
# **9. Exporte la conversión realizada previamente al directorio raiz.**

# %% [markdown]
# **10. Exporte el resultado del *buffer* a un directorio de su máquina local.**

# %% [markdown]
# # Misión terminada

# %% [markdown]
# ![minions-muchas-gracias.gif](data:image/gif;base64,...)
